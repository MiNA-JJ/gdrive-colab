# %% [markdown]
# <a href="https://colab.research.google.com/github/MiNA-JJ/gdrive-colab/blob/main/mina_jj_lab_gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("mina-jj-lab")
# Out:
# mina-jj-lab
