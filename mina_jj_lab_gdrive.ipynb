# %% [markdown]
# <a href="https://colab.research.google.com/github/MiNA-JJ/gdrive-colab/blob/1-create-project-structure/mina_jj_lab_gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_11360/286282275.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 import pandas as pd
#       5 data = pd.read_csv('/drive/Shareddrives/MiNA-JJ/somadata')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/drive/Shareddrives/MiNA-JJ/somadata')
print(data)
# Out:
# Empty DataFrame
# Columns: [textA,  textB,  textC]
# Index: []

# %%
print("mina-jj-lab")
print("changes")
# Out:
# mina-jj-lab
# changes
